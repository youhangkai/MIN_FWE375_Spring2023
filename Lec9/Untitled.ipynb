# %%
import seaborn as sns
import pandas as pd

pgs = sns.load_dataset("penguins")

pgs
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.set_style('whitegrid')
sns.relplot(data = pgs, x = 'bill_length_mm',
           y = 'bill_depth_mm', hue='species',
           size='body_mass_g', style='sex', kind='line')

# %%
import seaborn as sns
import pandas as pd

pgs = sns.load_dataset("penguins")

sns.displot(data = pgs, x = "body_mass_g", hue = "island")

sns.displot(data = pgs,
           x = "body_mass_g",
           hue = "island",
            multiple = "stack",
           kind = "kde")

# %%
# Jointplot

sns.jointplot(data = pgs,
             x = "flipper_length_mm",
             y = "bill_length_mm",
             hue = "species")

# %%
sns.pairplot(data=pgs, hue = "species")

# %%
g = sns.PairGrid(data=pgs, hue="species", corner = True)
g.map_lower(sns.kdeplot, hue = None, levels = 4, color="0.4")
g.map_lower(sns.scatterplot, marker="+")
g.map_diag(sns.histplot, kde=True)
g.add_legend()
g.legend.set_bbox_to_anchor((0.6,0.6))

# %%
# rugplot

sns.rugplot(data=pgs,
            x="flipper_length_mm",
            y="bill_depth_mm",
           hue = "species")
sns.scatterplot(data=pgs,
            x="flipper_length_mm",
            y="bill_depth_mm",
            hue="species")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='bill_depth_mm'>

# %%
# categorical plot

sns.catplot(data=pgs,
           x="species",
           y="bill_length_mm",
            hue="sex",
           kind="bar")

# %%
g = sns.lmplot(data=pgs,
               x="bill_length_mm",
               y="bill_depth_mm",
               hue = "species")
g.set_axis_labels("Snoot Length (mm)", "Snooth Depth (mm)")

# %%
g = sns.lmplot(data=pgs,
               x="bill_length_mm",
               y="bill_depth_mm",
               hue = "species",
              order = 3)
g.set_axis_labels("Snoot Length (mm)", "Snooth Depth (mm)")

# %%
g = sns.lmplot(data=pgs,
              x = "bill_length_mm",
              y = "bill_depth_mm",
              hue = "species",
              col = "island",
              row = "sex")

# %%
g = sns.FacetGrid(data = pgs,
                 row = "sex",
                 col = "species",
                  margin_titles = True)
g.map(sns.regplot, "bill_length_mm", "bill_depth_mm", color = "0.4")

# %%
import pandas as pd
import seaborn as sns
TD = pd.read_csv("TRENDYdata.csv")

TD = TD.loc[TD["tas"]<1000,]

g = sns.lmplot(data = TD,
                x = "tas",
                y = "npp",
               hue = "Model",
              col = "Model",
              col_wrap = 4,
              sharex = False)
# Out:
# /Users/minchen/opt/anaconda3/lib/python3.9/site-packages/seaborn/regression.py:592: UserWarning: sharex is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.lineplot(data = TD, x = "Year", y = "nbp")
g.set(xlim=(1960, 2010))
# Out:
# [(1960.0, 2010.0)]

# %%
sns.scatterplot(data=TD,
               x = "rh",
               y = "npp")

import numpy as np
TD["rh_bins"] = pd.cut(x = TD["rh"],
                      bins = np.linspace(40, 70, 4))
sns.catplot(data = TD,
           x = "rh_bins",
           y = "npp",
           kind = "violin")
